# %%
import requests
import os

bibliotecas = reque
















































sts.get("https://docs.google.com/spreadsheets/d/1udwn61l_FZsFsEuU8CMVkvU2SpwPW3Krt1OML3cYMYk/edit#gid=1605800889", allow_redirects= True)
os.makedirs('bibliotecas/2021-noviembre')
open('bibliotecas/2021-noviembre/bibiotecas-03-11-2021.csv', 'wb').write(bibliotecas.content)

museos = requests.get("https://docs.google.com/spreadsheets/d/1PS2_yAvNVEuSY0gI8Nky73TQMcx_G1i18lm--jOGfAA/edit#gid=514147473", allow_redirects= True)
os.makedirs('museos/2021-noviembre')
open('museos/2021-noviembre/museos-03-11-2021.csv', 'wb').write(museos.content)

salas_de_cine = requests.get("https://docs.google.com/spreadsheets/d/1o8QeMOKWm4VeZ9VecgnL8BWaOlX5kdCDkXoAph37sQM/edit#gid=1691373423", allow_redirects= True)
os.makedirs('salas_de_cine/2021-noviembre')
open('salas_de_cine/2021-noviembre/salas_de_cine-03-11-2021.csv', 'wb').write(salas_de_cine.content)
# Out:
# 388434

# %%
import pandas as pd

"""Creacion de las tablas"""

bibliotecas_df = pd.read_csv('bibliotecas/2021-noviembre/bibiotecas-03-11-2021.csv', index_col=0, parse_dates=['Quradate'])

print(bibliotecas_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\x\OneDrive\Escritorio\Agus\Practicando\Alkemy\probando.ipynb Celda 2 in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/x/OneDrive/Escritorio/Agus/Practicando/Alkemy/probando.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
#       <a href='vscode-notebook-cell:/c%3A/Users/x/OneDrive/Escritorio/Agus/Practicando/Alkemy/probando.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> """Creacion de las tablas"""
# ----> <a href='vscode-notebook-cell:/c%3A/Users/x/OneDrive/Escritorio/Agus/Practicando/Alkemy/probando.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a> bibliotecas_df = pd.read_csv('bibliotecas/2021-noviembre/bibiotecas-03-11-2021.csv', index_col=0, parse_dates=['Quradate'])
# ...

# %%
probando = pd.read_csv("https://docs.google.com/spreadsheets/d/1udwn61l_FZsFsEuU8CMVkvU2SpwPW3Krt1OML3cYMYk/edit#gid=1605800889", index_col=0,parse_dates=['Cod_Loc'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\x\OneDrive\Escritorio\Agus\Practicando\Alkemy\probando.ipynb Celda 3 in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/x/OneDrive/Escritorio/Agus/Practicando/Alkemy/probando.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> probando = pd.read_csv("https://docs.google.com/spreadsheets/d/1udwn61l_FZsFsEuU8CMVkvU2SpwPW3Krt1OML3cYMYk/edit#gid=1605800889", index_col=0,parse_dates=['Cod_Loc'])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
# ...

# %%
log.info('Loading google spreadsheet from {}'.format(url))

# %%
sheet_id = '1udwn61l_FZsFsEuU8CMVkvU2SpwPW3Krt1OML3cYMYk'
prueba = pd.read_csv(f"https://docs.google.com/spreadsheets/d/{sheet_id}/export?format=csv")

print(prueba.head())
# Out:
#     Cod_Loc  IdProvincia  IdDepartamento  Observacion              Categoría  \
# 0  70049060           70           70049          NaN  Bibliotecas Populares
# 1   2000010            2            2000          NaN  Bibliotecas Populares
# 2   2000010            2            2000          NaN  Bibliotecas Populares
# 3   2000010            2            2000          NaN  Bibliotecas Populares
# 4   2000010            2            2000          NaN  Bibliotecas Populares
#
#    Subcategoria                        Provincia  \
# 0           NaN                         San Juan
# 1           NaN  Ciudad Autónoma de Buenos Aires
# 2           NaN  Ciudad Autónoma de Buenos Aires
# 3           NaN  Ciudad Autónoma de Buenos Aires
# 4           NaN  Ciudad Autónoma de Buenos Aires
#
#                       Departamento               Localidad  \
# 0                          Iglesia                   Rodeo
# 1  Ciudad Autonoma de Buenos Aires  Ciudad de Buenos Aires
# ...

# %%
prueba = pd.DataFrame(prueba)

# %%
prueba
# Out:
#        Cod_Loc  IdProvincia  IdDepartamento  Observacion  \
# 0     70049060           70           70049          NaN
# 1      2000010            2            2000          NaN
# 2      2000010            2            2000          NaN
# 3      2000010            2            2000          NaN
# 4      2000010            2            2000          NaN
# ...        ...          ...             ...          ...
# 2012  62042560           62           62042          NaN
# 2013  70028010           70           70028          NaN
# 2014  62007080           62           62007          NaN
# 2015  62077010           62           62077          NaN
# 2016  62042360           62           62042          NaN
#
#                   Categoría  Subcategoria                        Provincia  \
# 0     Bibliotecas Populares           NaN                         San Juan
# 1     Bibliotecas Populares           NaN  Ciudad Autónoma de Buenos Aires
# ...

# %%
bibliotecas_id = '1udwn61l_FZsFsEuU8CMVkvU2SpwPW3Krt1OML3cYMYk'
bibliotecas = requests.get(f"https://docs.google.com/spreadsheets/d/{bibliotecas_id}/export?format=csv", allow_redirects= True)
os.makedirs('bibliotecas/2021-noviembre')
open('bibliotecas/2021-noviembre/bibliotecas-03-11-2021.csv', 'wb').write(bibliotecas.content)
# Out:
# 513840

# %%
bibliotecas = pd.read_csv('bibliotecas/2021-noviembre/bibliotecas-03-11-2021.csv')
# Out:
#        Cod_Loc  IdProvincia  IdDepartamento  Observacion  \
# 0     70049060           70           70049          NaN
# 1      2000010            2            2000          NaN
# 2      2000010            2            2000          NaN
# 3      2000010            2            2000          NaN
# 4      2000010            2            2000          NaN
# ...        ...          ...             ...          ...
# 2012  62042560           62           62042          NaN
# 2013  70028010           70           70028          NaN
# 2014  62007080           62           62007          NaN
# 2015  62077010           62           62077          NaN
# 2016  62042360           62           62042          NaN
#
#                   Categoría  Subcategoria                        Provincia  \
# 0     Bibliotecas Populares           NaN                         San Juan
# 1     Bibliotecas Populares           NaN  Ciudad Autónoma de Buenos Aires
# ...

# %%
bibliotecas_2= pd.DataFrame(bibliotecas)

print(bibliotecas_2)
# Out:
#        Cod_Loc  IdProvincia  IdDepartamento  Observacion  \
# 0     70049060           70           70049          NaN
# 1      2000010            2            2000          NaN
# 2      2000010            2            2000          NaN
# 3      2000010            2            2000          NaN
# 4      2000010            2            2000          NaN
# ...        ...          ...             ...          ...
# 2012  62042560           62           62042          NaN
# 2013  70028010           70           70028          NaN
# 2014  62007080           62           62007          NaN
# 2015  62077010           62           62077          NaN
# 2016  62042360           62           62042          NaN
#
#                   Categoría  Subcategoria                        Provincia  \
# 0     Bibliotecas Populares           NaN                         San Juan
# 1     Bibliotecas Populares           NaN  Ciudad Autónoma de Buenos Aires
# ...

# %%
import pandas as pd

# %%
prueba = pd.read_csv(r'bibliotecas\2021-noviembre\bibliotecas-03-11-2021.csv')
prueba.head(3)
# Out:
#     Cod_Loc  IdProvincia  IdDepartamento  Observacion              Categoría  \
# 0  70049060           70           70049          NaN  Bibliotecas Populares
# 1   2000010            2            2000          NaN  Bibliotecas Populares
# 2   2000010            2            2000          NaN  Bibliotecas Populares
#
#    Subcategoria                        Provincia  \
# 0           NaN                         San Juan
# 1           NaN  Ciudad Autónoma de Buenos Aires
# 2           NaN  Ciudad Autónoma de Buenos Aires
#
#                       Departamento               Localidad  \
# 0                          Iglesia                   Rodeo
# 1  Ciudad Autonoma de Buenos Aires  Ciudad de Buenos Aires
# 2  Ciudad Autonoma de Buenos Aires  Ciudad de Buenos Aires
#
#                                         Nombre  ...  \
# 0         Biblioteca Popular Juan P. Garramuno  ...
# 1  Biblioteca Popular Helena Larroque de Roffo  ...
# 2             Biblioteca Popular 12 de Octubre  ...
#
# ...

# %%
prueba = prueba.drop(['Observacion', 'Subcategoria', 'Información adicional','Cod_tel','Departamento','Piso', 'Latitud', 'Longitud', 'TipoLatitudLongitud', 'Fuente', 'Tipo_gestion', 'año_inicio', 'Año_actualizacion'], axis=1)

# %%
prueba.head(3)
# Out:
#     Cod_Loc  IdProvincia  IdDepartamento              Categoría  \
# 0  70049060           70           70049  Bibliotecas Populares
# 1   2000010            2            2000  Bibliotecas Populares
# 2   2000010            2            2000  Bibliotecas Populares
#
#                          Provincia               Localidad  \
# 0                         San Juan                   Rodeo
# 1  Ciudad Autónoma de Buenos Aires  Ciudad de Buenos Aires
# 2  Ciudad Autónoma de Buenos Aires  Ciudad de Buenos Aires
#
#                                         Nombre             Domicilio  \
# 0         Biblioteca Popular Juan P. Garramuno         Santo Domingo
# 1  Biblioteca Popular Helena Larroque de Roffo          Simbrón 3058
# 2             Biblioteca Popular 12 de Octubre  Calle Arengreen 1187
#
#          CP  Teléfono                            Mail  Web
# 0      5465       s/d                             s/d  NaN
# 1  C1417EUD  45010078    asociacionroffo@yahoo.com.ar  NaN
# ...

# %%
prueba = prueba.rename(columns={'Cod_Loc':'cod_localidad', 'IdProvincia':'id_provincia', 'IdDepartamento':'id_departamento', 'Categoría':'categoría', 'Provincia':'provincia', 'Localidad':'localidad', 'Nombre':'nombre', 'Domicilio':'domicilio', 'CP':'código_postal', 'Teléfono':'número_de_teléfono', 'Mail':'mail', 'Web':'web'})

# %%
prueba.head(3)
# Out:
#    cod_localidad  id_provincia  id_departamento              categoría  \
# 0       70049060            70            70049  Bibliotecas Populares
# 1        2000010             2             2000  Bibliotecas Populares
# 2        2000010             2             2000  Bibliotecas Populares
#
#                          provincia               localidad  \
# 0                         San Juan                   Rodeo
# 1  Ciudad Autónoma de Buenos Aires  Ciudad de Buenos Aires
# 2  Ciudad Autónoma de Buenos Aires  Ciudad de Buenos Aires
#
#                                         nombre             domicilio  \
# 0         Biblioteca Popular Juan P. Garramuno         Santo Domingo
# 1  Biblioteca Popular Helena Larroque de Roffo          Simbrón 3058
# 2             Biblioteca Popular 12 de Octubre  Calle Arengreen 1187
#
#   código_postal número_de_teléfono                            mail  web
# 0          5465                s/d                             s/d  NaN
# ...

# %%
prueba_3 = pd.read_csv(r'salas_de_cine\2021-noviembre\salas_de_cine-03-11-2021.csv')
prueba_3.head(5)
# Out:
#     Cod_Loc  IdProvincia  IdDepartamento  Observaciones      Categoría  \
# 0  10049030           10           10049            NaN  Salas de cine
# 1  10091150           10           10091            NaN  Salas de cine
# 2  22140060           22           22140            NaN  Salas de cine
# 3  26091020           26           26091            NaN  Salas de cine
# 4  18007010           18           18007            NaN  Salas de cine
#
#     Provincia  Departamento    Localidad                       Nombre  \
# 0   Catamarca       Capital    Catamarca                 Cinemacenter
# 1   Catamarca   Santa Maria  Santa María  Centro Cultural San Agustín
# 2       Chaco  San Fernando  Resistencia        Los Cines De La Costa
# 3      Chubut     Sarmiento    Sarmiento    Deborah Jones De Williams
# 4  Corrientes   Bella Vista  Bella Vista                     Fantasio
#
#                                Dirección  ... Información adicional  \
# ...

# %%
prueba_2 = pd.read_csv(r'museos\2021-noviembre\museos-03-11-2021.csv')
prueba_2.head(3)
# Out:
#    Cod_Loc  IdProvincia  IdDepartamento  Observaciones  \
# 0  6588100            6            6588            NaN
# 1  6077010            6            6077            NaN
# 2  6035010            6            6035            NaN
#
#                             categoria subcategoria     provincia   localidad  \
# 0  Espacios de Exhibición Patrimonial       Museos  Buenos Aires  9 de julio
# 1  Espacios de Exhibición Patrimonial       Museos  Buenos Aires   Arrecifes
# 2  Espacios de Exhibición Patrimonial       Museos  Buenos Aires  Avellaneda
#
#                                             nombre  \
# 0   Archivo Y Museo Histórico Gral. Julio De Vedia
# 1           Museo Y Archivo Histórico De Arrecifes
# 2  Museo Histórico-Sacro  Hno. Rogelio Scortegagna
#
#                           direccion  ...                        Mail  \
# 0                     Libertad 1191  ...  archivoymuseo@yahoo.com.ar
# 1            Gerardo Risso y España  ...  museoarrecifes@hotmail.com
# ...

# %%
prueba_2 = prueba_2.drop(['Observaciones', 'subcategoria', 'Info_adicional','piso','cod_area', 'Latitud', 'Longitud', 'TipoLatitudLongitud', 'fuente','jurisdiccion', 'año_inauguracion', 'actualizacion'], axis=1)
prueba_2.head(3)
# Out:
#    Cod_Loc  IdProvincia  IdDepartamento                           categoria  \
# 0  6588100            6            6588  Espacios de Exhibición Patrimonial
# 1  6077010            6            6077  Espacios de Exhibición Patrimonial
# 2  6035010            6            6035  Espacios de Exhibición Patrimonial
#
#       provincia   localidad                                           nombre  \
# 0  Buenos Aires  9 de julio   Archivo Y Museo Histórico Gral. Julio De Vedia
# 1  Buenos Aires   Arrecifes           Museo Y Archivo Histórico De Arrecifes
# 2  Buenos Aires  Avellaneda  Museo Histórico-Sacro  Hno. Rogelio Scortegagna
#
#                           direccion        CP telefono  \
# 0                     Libertad 1191  B6500EVL  425 279
# 1            Gerardo Risso y España  B2740FMJ  452 931
# 2  Calle 11 (Av. San Martín) Nº 830  S3561AKT  481 200
#
#                          Mail                    Web
# 0  archivoymuseo@yahoo.com.ar  www.portaldel9.com.ar
# ...

# %%
prueba_2 = prueba_2.rename(columns={'Cod_Loc':'cod_localidad', 'IdProvincia':'id_provincia', 'IdDepartamento':'id_departamento', 'categoria':'categoría', 'Domicilio':'domicilio', 'CP':'código_postal', 'telefono':'número_de_teléfono', 'Mail':'mail', 'Web':'web'})
prueba_2

# %%
prueba_2
# Out:
#       cod_localidad  id_provincia  id_departamento  \
# 0           6588100             6             6588
# 1           6077010             6             6077
# 2           6035010             6             6035
# 3           6035010             6             6035
# 4           6049020             6             6049
# ...             ...           ...              ...
# 1177       90098040            90            90098
# 1178       90105080            90            90105
# 1179       90105080            90            90105
# 1180       90105070            90            90105
# 1181       90098040            90            90098
#
#                                categoría     provincia          localidad  \
# 0     Espacios de Exhibición Patrimonial  Buenos Aires         9 de julio
# 1     Espacios de Exhibición Patrimonial  Buenos Aires          Arrecifes
# 2     Espacios de Exhibición Patrimonial  Buenos Aires         Avellaneda
# ...

# %%
prueba_3 = pd.read_csv(r'salas_de_cine\2021-noviembre\salas_de_cine-03-11-2021.csv')
prueba_3.head(5)
# Out:
#     Cod_Loc  IdProvincia  IdDepartamento  Observaciones      Categoría  \
# 0  10049030           10           10049            NaN  Salas de cine
# 1  10091150           10           10091            NaN  Salas de cine
# 2  22140060           22           22140            NaN  Salas de cine
# 3  26091020           26           26091            NaN  Salas de cine
# 4  18007010           18           18007            NaN  Salas de cine
#
#     Provincia  Departamento    Localidad                       Nombre  \
# 0   Catamarca       Capital    Catamarca                 Cinemacenter
# 1   Catamarca   Santa Maria  Santa María  Centro Cultural San Agustín
# 2       Chaco  San Fernando  Resistencia        Los Cines De La Costa
# 3      Chubut     Sarmiento    Sarmiento    Deborah Jones De Williams
# 4  Corrientes   Bella Vista  Bella Vista                     Fantasio
#
#                                Dirección  ... Información adicional  \
# ...

# %%
prueba_3 = prueba_3.drop(['Observaciones', 'Información adicional','Departamento','Piso', 'Latitud', 'Longitud', 'TipoLatitudLongitud', 'Fuente', 'tipo_gestion','cod_area',  'año_actualizacion'], axis=1)
prueba_3.head(3)
# Out:
#     Cod_Loc  IdProvincia  IdDepartamento      Categoría  Provincia  \
# 0  10049030           10           10049  Salas de cine  Catamarca
# 1  10091150           10           10091  Salas de cine  Catamarca
# 2  22140060           22           22140  Salas de cine      Chaco
#
#      Localidad                       Nombre                      Dirección  \
# 0    Catamarca                 Cinemacenter  Intendente Mamerto Medina 220
# 1  Santa María  Centro Cultural San Agustín                 San Martin 173
# 2  Resistencia        Los Cines De La Costa             Av. Sarmiento 2600
#
#      CP Teléfono                                     Mail  \
# 0  4700      s/d                                      s/d
# 1  4139   421511                                      s/d
# 2  3500   472200  administracion@loscinesdelacosta.com.ar
#
#                                             Web  Pantallas  Butacas  \
# 0               http://www.cinemacenter.com.ar/          5      743
# ...

# %%
prueba_3 = prueba_3.rename(columns={'Cod_Loc':'cod_localidad', 'IdProvincia':'id_provincia', 'IdDepartamento':'id_departamento', 'Categoría':'categoría', 'Dirección':'domicilio', 'CP':'código_postal', 'Teléfono':'número_de_teléfono', 'Mail':'mail', 'Web':'web'})
prueba_3
# Out:
#      cod_localidad  id_provincia  id_departamento      categoría  \
# 0         10049030            10            10049  Salas de cine
# 1         10091150            10            10091  Salas de cine
# 2         22140060            22            22140  Salas de cine
# 3         26091020            26            26091  Salas de cine
# 4         18007010            18            18007  Salas de cine
# ..             ...           ...              ...            ...
# 324        6455030             6             6455  Salas de cine
# 325        6434010             6             6434  Salas de cine
# 326        6791050             6             6791  Salas de cine
# 327       10049030            10            10049  Salas de cine
# 328        6427010             6             6427  Salas de cine
#
#         Provincia    Localidad                          Nombre  \
# 0       Catamarca    Catamarca                    Cinemacenter
# ...
